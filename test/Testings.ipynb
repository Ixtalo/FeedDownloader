# %%
import os
import feedparser
import requests
FEED_URL = 'https://www.presseportal.de/rss/dienststelle_110972.rss2'

# %%
d = feedparser.parse(FEED_URL)
d
# Out:
# {'feed': {'title': 'Presseportal.de - Polizeipräsidium Karlsruhe',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'https://www.presseportal.de/rss/dienststelle_110972.rss2',
#    'value': 'Presseportal.de - Polizeipräsidium Karlsruhe'},
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'https://www.presseportal.de/blaulicht/pm/110972/polizeipr-sidium-karlsruhe/rss'},
#    {'href': 'https://www.presseportal.de/rss/dienststelle_110972.rss2',
#     'rel': 'self',
#     'type': 'application/rss+xml'}],
#   'link': 'https://www.presseportal.de/blaulicht/pm/110972/polizeipr-sidium-karlsruhe/rss',
#   'subtitle': 'Portal für aktuelle Presseinformationen von diversen Polizeistationen in Deutschland',
#   'subtitle_detail': {'type': 'text/html',
#    'language': None,
#    'base': 'https://www.presseportal.de/rss/dienststelle_110972.rss2',
# ...

# %%
d.keys()
# Out:
# dict_keys(['feed', 'entries', 'bozo', 'headers', 'href', 'status', 'encoding', 'version', 'namespaces'])

# %%
d['bozo']
# Out:
# 0

# %%
d['headers']
# Out:
# {'Date': 'Tue, 12 May 2020 10:28:07 GMT',
#  'Server': 'Apache',
#  'Cache-Control': 'no-store, no-cache, must-revalidate, max-age=0',
#  'Pragma': 'no-cache',
#  'Connection': 'close',
#  'Content-Type': 'application/xml; charset=UTF-8',
#  'Set-Cookie': 'PortalPortalDeDst=300394688.20992.0000; path=/'}

# %%
d['feed']
# Out:
# {'title': 'Presseportal.de - Polizeipräsidium Karlsruhe',
#  'title_detail': {'type': 'text/plain',
#   'language': None,
#   'base': 'https://www.presseportal.de/rss/dienststelle_110972.rss2',
#   'value': 'Presseportal.de - Polizeipräsidium Karlsruhe'},
#  'links': [{'rel': 'alternate',
#    'type': 'text/html',
#    'href': 'https://www.presseportal.de/blaulicht/pm/110972/polizeipr-sidium-karlsruhe/rss'},
#   {'href': 'https://www.presseportal.de/rss/dienststelle_110972.rss2',
#    'rel': 'self',
#    'type': 'application/rss+xml'}],
#  'link': 'https://www.presseportal.de/blaulicht/pm/110972/polizeipr-sidium-karlsruhe/rss',
#  'subtitle': 'Portal für aktuelle Presseinformationen von diversen Polizeistationen in Deutschland',
#  'subtitle_detail': {'type': 'text/html',
#   'language': None,
#   'base': 'https://www.presseportal.de/rss/dienststelle_110972.rss2',
#   'value': 'Portal für aktuelle Presseinformationen von diversen Polizeistationen in Deutschland'},
# ...

# %%
d['entries'][0]
# Out:
# {'title': 'POL-KA: (KA) Philippsburg - Rollerfahrer stürzt alleinbeteiligt',
#  'title_detail': {'type': 'text/plain',
#   'language': None,
#   'base': 'https://www.presseportal.de/rss/dienststelle_110972.rss2',
#   'value': 'POL-KA: (KA) Philippsburg - Rollerfahrer stürzt alleinbeteiligt'},
#  'summary': 'Karlsruhe (ots) - Ein 53-jähriger Rollerfahrer stürzte am Montag gegen 17:50 Uhr auf einem neben der Bundesstraße 35 verlaufenden Radweg. Aus bislang unklaren Gründen touchierte der Rollerfahrer auf der Rheinbrücke aus Richtung Germersheim ...',
#  'summary_detail': {'type': 'text/html',
#   'language': None,
#   'base': 'https://www.presseportal.de/rss/dienststelle_110972.rss2',
#   'value': 'Karlsruhe (ots) - Ein 53-jähriger Rollerfahrer stürzte am Montag gegen 17:50 Uhr auf einem neben der Bundesstraße 35 verlaufenden Radweg. Aus bislang unklaren Gründen touchierte der Rollerfahrer auf der Rheinbrücke aus Richtung Germersheim ...'},
#  'links': [{'rel': 'alternate',
# ...

# %%
d.entries[0].link
# Out:
# 'https://www.presseportal.de/blaulicht/pm/110972/4594855'

# %%
requests.utils.urlparse(FEED_URL).path
# Out:
# '/rss/dienststelle_110972.rss2'

# %%
os.path.basename(requests.utils.urlparse(FEED_URL).path)
# Out:
# 'dienststelle_110972.rss2'
